# %% [markdown]
# **Task To Do**

# %% [markdown]
# 7.1 Warming up exercise

# %% [markdown]
# Task 1. Classify Temperatures:

# %% [markdown]
# 1. Create empty lists for temperature classifications:
#
# (a) Cold: temperatures below 10°C.
#
# (b) Mild: temperatures between 10°C and 15°C.
#
# (c) Comfortable: temperatures between 15°C and 20°C.
#
# 2. Iterate over the temperatures list and add each temperature to the appropriate category.
#
# 3. Print the lists to verify the classifications.

# %%
# 1. Create empty lists for classifications
cold = []
mild = []
comfortable = []

# 2. Classify temperatures
temperatures = [5, 12, 18, 8, 14, 17, 3]
for temp in temperatures:
    if temp < 10:
        cold.append(temp)
    elif 10 <= temp < 15:
        mild.append(temp)
    elif 15 <= temp < 20:
        comfortable.append(temp)

# 3. Print the classified lists
print("Cold:", cold)
print("Mild:", mild)
print("Comfortable:", comfortable)
# Out:
# Cold: [5, 8, 3]
# Mild: [12, 14]
# Comfortable: [18, 17]

# %% [markdown]
# Task 2. Based on Data - Answer all the Questions:
# 1. How many times was it mild?
# (a) Hint: Count the number of items in the mild list and print the result.
#
# 2. How many times was it comfortable?
#
# 3. How many times was it cold?

# %%
# 1. How many times was it mild?
mild_count = len(mild)
print(f"Number of mild temperatures: {mild_count}")

# 2. How many times was it comfortable?
comfortable_count = len(comfortable)
print(f"Number of comfortable temperatures: {comfortable_count}")

# 3. How many times was it cold?
cold_count = len(cold)
print(f"Number of cold temperatures: {cold_count}")
# Out:
# Number of mild temperatures: 2
# Number of comfortable temperatures: 2
# Number of cold temperatures: 3

# %% [markdown]
# Task 3. Convert Temperatures from Celsius to Fahrenheit
#
# Using the formula for temperature conversion, convert each reading from Celsius to Fahrenheit and store it in a new list called temperatures_fahrenheit.
#
#          Formula: Fahrenheit = (Celsius × 9/5) + 32
#
# 1. Iterate over the temperatures list and apply the formula to convert each temperature.
#
# 2. Store the results in the new list.
#
# 3. Print the converted Fahrenheit values.

# %%
#1 Celsius temperatures
temperatures = [5, 12, 18, 8, 14, 17, 3]

# 2. Create an empty list for Fahrenheit values
temperatures_fahrenheit = []

# 3. Convert Celsius to Fahrenheit
for temp in temperatures:
    fahrenheit = (temp * 9 / 5) + 32
    temperatures_fahrenheit.append(fahrenheit)

# 4. Print the converted Fahrenheit values
print("Temperatures in Fahrenheit:", temperatures_fahrenheit)
# Out:
# Temperatures in Fahrenheit: [41.0, 53.6, 64.4, 46.4, 57.2, 62.6, 37.4]

# %% [markdown]
# Task 4. Analyze Temperature Patterns by Time of Day:
#
# Scenario: Each day’s readings are grouped as:
#
# • Night (00-08),
# • Evening (08-16),
# • Day (16-24).
#
# 1. Create empty lists for night, day, and evening temperatures.
#
# 2. Iterate over the temperatures list, assigning values to each time-of-day list based on
# their position.
#
# 3. Calculate and print the average day-time temperature.
#
# 4. (Optional) Plot ”day vs. temperature” using matplotlib

# %%
import matplotlib.pyplot as plt

# 1. Example temperatures with their time of day
temperatures = [5, 6, 7, 8, 12, 14, 15, 18, 19, 20, 10, 8, 6, 5, 4, 3]

# 2. Create empty lists for each time of day
night = []
evening = []
day = []

# 3. Classify temperatures by time of day
for i, temp in enumerate(temperatures):
    if 0 <= i < 8:  # Night
        night.append(temp)
    elif 8 <= i < 16:  # Evening
        evening.append(temp)
    elif 16 <= i < 24:  # Day
        day.append(temp)

# 4. Calculate the average daytime temperature
if day:
    avg_day_temp = sum(day) / len(day)
    print(f"Average day-time temperature: {avg_day_temp:.2f}°C")
else:
    print("No day-time temperatures available for analysis.")

# 5. Plot the temperatures
time_of_day = ["Night", "Evening", "Day"]
average_temperatures = [
    sum(night) / len(night) if night else 0,
    sum(evening) / len(evening) if evening else 0,
    avg_day_temp if day else 0,
]

plt.figure(figsize=(8, 5))
plt.bar(time_of_day, average_temperatures, color=['blue', 'orange', 'green'])
plt.title("Average Temperatures by Time of Day")
plt.xlabel("Time of Day")
plt.ylabel("Temperature (°C)")
plt.show()
# Out:
# No day-time temperatures available for analysis.

# %% [markdown]
# **8.1.1 Exercise - Recursion:**

# %% [markdown]
# Task 1 - Sum of Nested Lists:
#
# Scenario: You have a list that contains numbers and other lists of numbers (nested lists).
#
# You want to find the total sum of all the numbers in this structure.
#
# Task:
#
# • Write a recursive function sum_nested_list(nested_list) that:
#
# 1. Takes a nested list (a list that can contain numbers or other lists of numbers) as
# input.
#
# 2. Sums all numbers at every depth level of the list, regardless of how deeply nested
# the numbers are.
#
# • Test the function with a sample nested list, such as
# nested_list = [1, [2, [3, 4], 5], 6, [7, 8]].
#
# The result should be the total sum of all the numbers.

# %%
def sum_nested_list(nested_list):
    """
    Recursively calculates the sum of all numbers in a nested list structure.

    :param nested_list: A list that may contain integers or other nested lists
    :return: The total sum of all integers in the nested structure
    """
    total = 0
    for element in nested_list:
        if isinstance(element, list):  # Check if the element is a list
            total += sum_nested_list(element)  # Recursive call for nested lists
        else:
            total += element  # Add the number directly if it's not a list
    return total

# Testing the function with a sample nested list
nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
result = sum_nested_list(nested_list)
print(f"The total sum of the nested list {nested_list} is: {result}")
# Out:
# The total sum of the nested list [1, [2, [3, 4], 5], 6, [7, 8]] is: 36

# %% [markdown]
# Task 2 - Generate All Permutations of a String:
#
# Scenario: Given a string, generate all possible permutations of its characters. This is useful
# for understanding backtracking and recursive depth-first search.
#
# Task:
#
# • Write a recursive function generate_permutations(s) that:
#
# – Takes a string s as input and returns a list of all unique permutations.
# • Test with strings like ”abc” and ”aab”.
#
# print(generate_permutations("abc"))
#  Should return [’abc’, ’acb’, ’bac’, ’bca’, ’cab’, ’cba’]

# %%
def generate_permutations(s):
    """
    Generates all unique permutations of a given string.

    :param s: Input string
    :return: List of unique permutations
    """
    if len(s) == 1:  # Base case: a single character string has one permutation
        return [s]

    permutations = []  # List to store all permutations
    for i, char in enumerate(s):
        # Exclude the current character and permute the remaining
        remaining = s[:i] + s[i+1:]
        for perm in generate_permutations(remaining):
            # Add the current character to the beginning of each permutation
            permutations.append(char + perm)

    return list(set(permutations))  # Ensure uniqueness by converting to a set, then back to a list

# Testing the function
print(generate_permutations("abc"))
print(generate_permutations("aab"))
# Out:
# ['cba', 'bca', 'bac', 'acb', 'abc', 'cab']
# ['baa', 'aba', 'aab']

# %% [markdown]
# Task 3 - Directory Size Calculation:
#
# Task:
# 1. Write a recursive function calculate_directory_size(directory) where:
#
#   • directory is a dictionary where keys represent file names (with values as sizes in
# KB) or directory names (with values as another dictionary representing a subdirectory).
#
#   • The function should return the total size of the directory, including all nested
# subdirectories.
#
# 2. Test the function with a sample directory structure.

# %%
def calculate_directory_size(directory):
    """
    Recursively calculates the total size of a directory, including nested subdirectories.

    :param directory: A dictionary where keys are file or directory names and values are:
                      - integers (file sizes in KB) or
                      - dictionaries (subdirectories)
    :return: Total size of the directory in KB
    """
    total_size = 0
    for key, value in directory.items():
        if isinstance(value, dict):  # If the value is a dictionary, it's a subdirectory
            total_size += calculate_directory_size(value)  # Recursively calculate its size
        else:  # Otherwise, it's a file with a size
            total_size += value
    return total_size

# Testing the function with a sample directory structure
sample_directory = {
    "file1.txt": 120,
    "file2.txt": 200,
    "subdir1": {
        "file3.txt": 150,
        "subdir2": {
            "file4.txt": 300,
            "file5.txt": 400
        }
    },
    "file6.txt": 50
}

# Calculate and print the total size
result = calculate_directory_size(sample_directory)
print(f"The total size of the directory is: {result} KB")
# Out:
# The total size of the directory is: 1220 KB

# %% [markdown]
# **8.2 Dynamic Programming:**

# %% [markdown]
# 8.2.2 Exercises - Dynamic Programming:

# %% [markdown]
# Task 1 - Coin Change Problem:
#
# Scenario: Given a set of coin denominations and a target amount, find the minimum number
# of coins needed to make the amount. If it’s not possible, return - 1.
#
# Task:
# 1. Write a function min_coins(coins, amount) that:
#
#    • Uses DP to calculate the minimum number of coins needed to make up the
# amount.
#
# 2. Test with coins = [1, 2, 5] and amount = 11. The result should be 3 (using coins
# [5, 5, 1]).

# %%
def min_coins(coins, amount):
    """
    Calculates the minimum number of coins needed to make the given amount.

    :param coins: List of available coin denominations
    :param amount: The target amount to form using the coins
    :return: The minimum number of coins needed, or -1 if it's not possible
    """
    # Initialize the DP table with a large number (amount + 1)
    dp = [amount + 1] * (amount + 1)
    dp[0] = 0  # Base case: 0 coins needed to make 0 amount

    for coin in coins:
        for i in range(coin, amount + 1):
            dp[i] = min(dp[i], dp[i - coin] + 1)

    # If dp[amount] is still the initial large number, it's not possible to make the amount
    return dp[amount] if dp[amount] <= amount else -1

# Test the function with the given example
coins = [1, 2, 5]
amount = 11
result = min_coins(coins, amount)
print(f"The minimum number of coins needed to make {amount} is: {result}")
# Out:
# The minimum number of coins needed to make 11 is: 3

# %% [markdown]
# Task 2 - Longest Common Subsequence (LCS):
#
# Scenario: Given two strings, find the length of their longest common subsequence (LCS).
# This is useful in text comparison.
#
# Task:
# 1. Write a function longest_common_subsequence(s1, s2) that:
#
#    • Uses DP to find the length of the LCS of two strings s1 and s2.
#
# 2. Test with strings like "abcde" and "ace"; the LCS length should be 3 ("ace").

# %%
def longest_common_subsequence(s1, s2):
    """
    Finds the length of the longest common subsequence (LCS) between two strings.

    :param s1: First string
    :param s2: Second string
    :return: Length of the longest common subsequence
    """
    m, n = len(s1), len(s2)

    # Create a 2D DP table with dimensions (m+1) x (n+1)
    dp = [[0] * (n + 1) for _ in range(m + 1)]

    # Fill the DP table
    for i in range(1, m + 1):
        for j in range(1, n + 1):
            if s1[i - 1] == s2[j - 1]:  # If characters match, LCS increases by 1
                dp[i][j] = dp[i - 1][j - 1] + 1
            else:  # If characters don't match, take the maximum of excluding one character at a time
                dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])

    # The bottom-right cell contains the length of the LCS
    return dp[m][n]

# Test the function with the given example
s1 = "abcde"
s2 = "ace"
result = longest_common_subsequence(s1, s2)
print(f"The length of the longest common subsequence is: {result}")
# Out:
# The length of the longest common subsequence is: 3
# The length of the longest common subsequence is: 3

# %% [markdown]
# Task 3 - 0/1 Knapsack Problem:
#
# Scenario: You have a list of items, each with a weight and a value. Given a weight capacity,
# maximize the total value of items you can carry without exceeding the weight capacity.
#
# Task:
# 1. Write a function knapsack(weights, values, capacity) that:
#
#    • Uses DP to determine the maximum value that can be achieved within the given
# weight capacity.
#
# 2. Test with weights [1, 3, 4, 5], values [1, 4, 5, 7], and capacity 7. The result should be 9.

# %%
def knapsack(weights, values, capacity):
    """
    Solves the 0/1 Knapsack problem using dynamic programming.

    :param weights: List of weights of the items
    :param values: List of values of the items
    :param capacity: The maximum weight capacity of the knapsack
    :return: Maximum value that can be carried in the knapsack
    """
    n = len(weights)

    # Create a DP table with dimensions (n+1) x (capacity+1)
    dp = [[0] * (capacity + 1) for _ in range(n + 1)]

    # Fill the DP table
    for i in range(1, n + 1):
        for w in range(1, capacity + 1):
            if weights[i - 1] <= w:  # Item i can be included in the knapsack
                dp[i][w] = max(dp[i - 1][w], dp[i - 1][w - weights[i - 1]] + values[i - 1])
            else:  # Item i cannot be included, so carry over the value from the previous row
                dp[i][w] = dp[i - 1][w]

    # The bottom-right cell contains the maximum value we can achieve
    return dp[n][capacity]

# Test the function with the given example
weights = [1, 3, 4, 5]
values = [1, 4, 5, 7]
capacity = 7
result = knapsack(weights, values, capacity)
print(f"The maximum value that can be carried in the knapsack is: {result}")
# Out:
# The maximum value that can be carried in the knapsack is: 9
